# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
table =pd.read_csv('/content/sample_data/bestsellers with categories.csv')
table
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  User Rating  Reviews  Price  Year        Genre
# 0                    JJ Smith          4.7    17350      8  2016  Non Fiction
# 1                Stephen King          4.6     2052     22  2011      Fiction
# ...

# %%
new_table = table[['Name', 'User Rating', 'Price', 'Year']]

# %%
tb = new_table[(new_table['Year'] == 2010) & (new_table['User Rating'] > 4.6)]

# %%
tb
# Out:
#                                                   Name  User Rating  Price  \
# 31   Barefoot Contessa, How Easy Is That?: Fabulous...          4.7     21
# 46                    Catching Fire (The Hunger Games)          4.7     11
# 51         Crazy Love: Overwhelmed by a Relentless God          4.7     14
# 264  Percy Jackson and the Olympians Paperback Boxe...          4.8      2
# 284  Radical: Taking Back Your Faith from the Ameri...          4.7      9
# 296                                   Sh*t My Dad Says          4.7     11
# 320  The 5 Love Languages: The Secret to Love That ...          4.7     28
# 340             The Art of Racing in the Rain: A Novel          4.7     10
# 342         The Big Short: Inside the Doomsday Machine          4.7     17
# 384  The Girl Who Kicked the Hornet's Nest (Millenn...          4.7     14
# 386  The Girl Who Played with Fire (Millennium Series)          4.7      9
# ...

# %%
plt.figure(figsize=(20,10))
ax = sns.barplot(y='Price', x='Name', data=tb)
ax.set_title("Ціни на книги 2010 року з рейтингом вище 4,6")
ax.set_ylabel("Price")
ax.set_xlabel("Name Book")
ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
plt.tight_layout()
plt.show()
