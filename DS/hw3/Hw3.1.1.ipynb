# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(50, 10))
date = ("Крим","Вінницька","Волинська","Дніпропетровська","Донецька","Житомирська","Закарпатська","Запорізька","Івано-Франківська","Київська","Кіровоградська","Луганська","Львівська","Миколаївська","Одеська","Полтавська","Рівненська","Сумська","Тернопільська","Харківська","Херсонська","Хмельницька","Черкаська","Чернівецька","Чернігівська","Київ","Севастополь")
plt.plot(date, [13.0, 12.4, 15.3, 12.3, 10.9, 12.9, 16.8, 12.4, 15.5, 12.3, 12.6, 11.6, 14.0, 13.7, 12.6, 11.8, 15.8, 11.5, 14.2, 11.4, 14.3, 12.9, 12.3, 14.8, 10.8, 12.0, 12.5])
plt.xlabel('Регіон', fontsize='large', color='midnightblue')
plt.title('Середня народжуваність у 1990 році', fontsize=15)
#diagram = table_column["1990"].plot.bar(rot=27, color=["y","b"], title="Средняя рождаемость в 1990 году")
# Out:
# Text(0.5, 1.0, 'Середня народжуваність у 1990 році')
