# %%
import pandas as pd

# %%
table =pd.read_csv('/content/sample_data/bestsellers with categories.csv')
table
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  User Rating  Reviews  Price  Year        Genre
# 0                    JJ Smith          4.7    17350      8  2016  Non Fiction
# 1                Stephen King          4.6     2052     22  2011      Fiction
# ...

# %%
table.head()
# Out:
#                                                 Name  \
# 0                      10-Day Green Smoothie Cleanse
# 1                                  11/22/63: A Novel
# 2            12 Rules for Life: An Antidote to Chaos
# 3                             1984 (Signet Classics)
# 4  5,000 Awesome Facts (About Everything!) (Natio...
#
#                      Author  User Rating  Reviews  Price  Year        Genre
# 0                  JJ Smith          4.7    17350      8  2016  Non Fiction
# 1              Stephen King          4.6     2052     22  2011      Fiction
# 2        Jordan B. Peterson          4.7    18979     15  2018  Non Fiction
# 3             George Orwell          4.7    21424      6  2017      Fiction
# 4  National Geographic Kids          4.8     7665     12  2019  Non Fiction

# %%
table.shape
# Out:
# (550, 7)

# %%
Ответ: О скольки книгах хранит данные датасет? Ответ 550 книг

# %%
table.columns = ['name', 'author', 'user_rating', 'reviews', 'price', 'year', 'genre']
table
# Out:
#                                                   name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        author  user_rating  reviews  price  year        genre
# 0                    JJ Smith          4.7    17350      8  2016  Non Fiction
# 1                Stephen King          4.6     2052     22  2011      Fiction
# ...

# %%
table.isna().sum()
# Out:
# name           0
# author         0
# user_rating    0
# reviews        0
# price          0
# year           0
# genre          0
# dtype: int64

# %% [markdown]
# Есть ли в каких либо переменных пропуски? Ответ: Нет

# %%
table['genre'].unique()
# Out:
# array(['Non Fiction', 'Fiction'], dtype=object)

# %% [markdown]
# Какие есть уникальные жанры? Ответ: 'Non Fiction', 'Fiction'

# %%
diagram = table.plot(y='price', kind='hist', color='red',  title='Распределение цен')

# %%
table['price'].min()
# Out:
# 0

# %%
table['price'].max()
# Out:
# 105

# %%
table['price'].mean()
# Out:
# 13.1

# %%
table['price'].median()
# Out:
# 11.0

# %% [markdown]
# Mаксимальная цена? Ответ: 105
# Минимальная цена? Ответ: 0
# Средняя цена? Ответ: 13.1
# Медианная цена? Ответ: 11.0

# %%
high_dataset = table['user_rating'].max()

# %%
high_dataset
# Out:
# 4.9

# %% [markdown]
# Какой рейтинг в датасете наивысший? Ответ: 4.9

# %%
len(table[table['user_rating'] == high_dataset])
# Out:
# 52

# %% [markdown]
# Сколько книг имеют такой рейтинг? Ответ: 52

# %%
max_review = table['reviews'].max()

# %%
table_v1 = table[['name', 'reviews']]

# %%
table_v1[table_v1['reviews'] == max_review]
# Out:
#                         name  reviews
# 534  Where the Crawdads Sing    87841

# %% [markdown]
# У какой книги больше всего отзывов? Ответ: Where the Crawdads Sing

# %%
new_task = table[['name', 'user_rating', 'price', 'year']]

# %%
new_task_v1 = new_task[new_task['user_rating'] == high_dataset]

# %%
year = new_task_v1[new_task_v1['year'] == 2015]

# %%
price = year['price'].max()

# %%
year = year[year['price'] == price]

# %%
year
# Out:
#                              name  user_rating  price  year
# 174  Humans of New York : Stories          4.9     17  2015

# %% [markdown]
# Из тех книг, что попали в Топ-50 в 2015 году, какая книга самая дорогая (можно использовать промежуточный датафрейм)? Ответ: Humans of New York : Stories

# %%
task_fiction = table[['genre', 'year']]

# %%
task_fiction_v1 = task_fiction[(task_fiction['genre'] == 'Fiction') & (task_fiction['year'] == 2010)]

# %%
len(task_fiction_v1), task_fiction_v1.shape
# Out:
# (20, (20, 2))

# %% [markdown]
# Сколько книг жанра Fiction попали в Топ-50 в 2010 году (используйте &)? Ответ: 20

# %%
how_many_books = table[((table['year'] == 2010) | (table['year'] == 2011)) & ((table['user_rating'] == 4.9))]

# %%
len(how_many_books)
# Out:
# 1

# %% [markdown]
# Сколько книг c рейтингом 4.9 попало в рейтинг в 2010 и 2011 годах (используйте | или функцию isin)? Ответ: 1

# %%
sort_books = table[(table['year'] == 2015) & (table['price'] < 8)]

# %%
sort_books.sort_values(by=['price'])
# Out:
#                                                   name              author  \
# 507                              To Kill a Mockingbird          Harper Lee
# 210                      Laugh-Out-Loud Jokes for Kids         Rob Elliott
# 206                         Knock-Knock Jokes for Kids         Rob Elliott
# 111                                    First 100 Words        Roger Priddy
# 123                               Giraffes Can't Dance       Giles Andreae
# 54   Creative Haven Creative Cats Coloring Book (Ad...     Marjorie Sarnat
# 63                      Dear Zoo: A Lift-the-Flap Book        Rod Campbell
# 89   Dover Creative Haven Art Nouveau Animal Design...         Marty Noble
# 478                        The Very Hungry Caterpillar          Eric Carle
# 201  Killing Reagan: The Violent Assault That Chang...       Bill O'Reilly
# 28                        Baby Touch and Feel: Animals                  DK
# ...

# %% [markdown]
# Какая книга последняя в отсортированном списке? Ответ: Old School (Diary of a Wimpy Kid #10)

# %%
task3 = table.groupby(['genre'])[['price']].agg(['min', 'max'])

# %%
task3
# Out:
#             price
#               min  max
# genre
# Fiction         0   82
# Non Fiction     0  105

# %% [markdown]
# Максимальная цена для жанра Fiction: Ответ: 82
# Минимальная цена для жанра Fiction: Ответ: 0
# Максимальная цена для жанра Non Fiction: Ответ: 105
# Минимальная цена для жанра Non Fiction: Ответ: 0

# %%
data = table.groupby(['author'])[['name']].agg(['count'])

# %%
data1 = data.reset_index()

# %%
data1
# Out:
#                          author  name
#                                 count
# 0              Abraham Verghese     2
# 1                Adam Gasiewski     1
# 2                 Adam Mansbach     1
# 3                     Adir Levy     1
# 4    Admiral William H. McRaven     1
# ..                          ...   ...
# 243             Walter Isaacson     3
# 244               William Davis     2
# 245            William P. Young     2
# 246            Wizards RPG Team     3
# 247                Zhi Gang Sha     2
#
# [248 rows x 2 columns]

# %%
data.shape
# Out:
# (248, 1)

# %% [markdown]
# Какой размерности вышла таблица? Ответ: (248, 1)

# %%
data[data[('name', 'count')] == data.max()[('name', 'count')]]
# Out:
#              name
#             count
# author
# Jeff Kinney    12

# %% [markdown]
# У какого автора больше всего книг? Ответ: Jeff Kinney
# Сколько книг у этого автора? Ответ: 12

# %%
data2 = table.groupby(['author'])[['user_rating']].agg(['mean'])

# %%
data2
# Out:
#                            user_rating
#                                   mean
# author
# Abraham Verghese              4.600000
# Adam Gasiewski                4.400000
# Adam Mansbach                 4.800000
# Adir Levy                     4.800000
# Admiral William H. McRaven    4.700000
# ...                                ...
# Walter Isaacson               4.566667
# William Davis                 4.400000
# William P. Young              4.600000
# Wizards RPG Team              4.800000
# Zhi Gang Sha                  4.600000
#
# [248 rows x 1 columns]

# %%
data2[data2[('user_rating', 'mean')] == data2.min()[('user_rating', 'mean')]]
# Out:
#             user_rating
#                    mean
# author
# Donna Tartt         3.9

# %% [markdown]
# У какого автора средний рейтинг минимальный? Ответ: Donna Tartt
# Какой у этого автора средний рейтинг? Ответ: 3.9

# %%
new_table = pd.concat([data, data2[('user_rating', 'mean')]], axis=1)

# %%
new_table
# Out:
#                             name user_rating
#                            count        mean
# author
# Abraham Verghese               2    4.600000
# Adam Gasiewski                 1    4.400000
# Adam Mansbach                  1    4.800000
# Adir Levy                      1    4.800000
# Admiral William H. McRaven     1    4.700000
# ...                          ...         ...
# Walter Isaacson                3    4.566667
# William Davis                  2    4.400000
# William P. Young               2    4.600000
# Wizards RPG Team               3    4.800000
# Zhi Gang Sha                   2    4.600000
#
# [248 rows x 2 columns]

# %%
sort = new_table.sort_values(by=[('user_rating', 'mean'), ('name', 'count')])

# %%
sort
# Out:
#                        name user_rating
#                       count        mean
# author
# Donna Tartt               2         3.9
# Muriel Barbery            1         4.0
# Gillian Flynn             3         4.0
# Gallup                    9         4.0
# Chris Cleave              1         4.1
# ...                     ...         ...
# Sherri Duskey Rinker      2         4.9
# Emily Winfield Martin     4         4.9
# Sarah Young               6         4.9
# Dav Pilkey                7         4.9
# Eric Carle                7         4.9
#
# [248 rows x 2 columns]

# %% [markdown]
# Какой автор первый в списке? Ответ: Donna Tartt
