# %%
import numpy
import keras
from keras.datasets import cifar10
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dropout
from keras.layers import Flatten
from keras.constraints import maxnorm
from keras.optimizers import SGD
from keras.layers.convolutional import Conv2D
from keras.layers.convolutional import MaxPooling2D
from keras.utils import np_utils
from keras import backend as K
if K.image_data_format() == 'channels_first':
    input_shape = (3, 32, 32)
else:
    input_shape = (32, 32, 3)

(X_train, y_train), (X_test, y_test) = cifar10.load_data()


# normalize inputs from 0-255 to 0.0-1.0
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')
X_train = X_train / 255.0
X_test = X_test / 255.0

y_train = np_utils.to_categorical(y_train)
y_test = np_utils.to_categorical(y_test)
num_classes = y_test.shape[1]

model = Sequential()
model.add(Conv2D(32, (3, 3), input_shape=(32, 32, 3), activation='relu', padding='same'))
model.add(Dropout(0.2))
model.add(Conv2D(32, (3, 3), activation='relu', padding='same'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Conv2D(64, (3, 3), activation='relu', padding='same'))
model.add(Dropout(0.2))
model.add(Conv2D(64, (3, 3), activation='relu', padding='same'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Conv2D(128, (3, 3), activation='relu', padding='same'))
model.add(Dropout(0.2))
model.add(Conv2D(128, (3, 3), activation='relu', padding='same'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Flatten())
model.add(Dropout(0.2))
model.add(Dense(1024, activation='relu', kernel_constraint=maxnorm(3)))
model.add(Dropout(0.2))
model.add(Dense(512, activation='relu', kernel_constraint=maxnorm(3)))
model.add(Dropout(0.2))
model.add(Dense(num_classes, activation='softmax'))
# Compile model
epochs = 30
lrate = 0.01
decay = lrate/epochs
sgd = SGD(lr=lrate, momentum=0.9, decay=decay, nesterov=False)
model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['accuracy'])
print(model.summary())

# Fit the model
model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=epochs, batch_size=64)
# Final evaluation of the model
scores = model.evaluate(X_test, y_test, verbose=0)
print("Accuracy: %.2f%%" % (scores[1]*100))

for k in model.layers:
    if type(k) is keras.layers.Dropout:
        model.layers.remove(k)

model.save('classify_app')
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 [==============================] - 3s 0us/step
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 32, 32, 32)        896
#
#  dropout (Dropout)           (None, 32, 32, 32)        0
#
#  conv2d_1 (Conv2D)           (None, 32, 32, 32)        9248
#
#  max_pooling2d (MaxPooling2D  (None, 16, 16, 32)       0
#  )
#
#  conv2d_2 (Conv2D)           (None, 16, 16, 64)        18496
#
#  dropout_1 (Dropout)         (None, 16, 16, 64)        0
#
#  conv2d_3 (Conv2D)           (None, 16, 16, 64)        36928
#
#  max_pooling2d_1 (MaxPooling  (None, 8, 8, 64)         0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 8, 8, 128)         73856
#
#  dropout_2 (Dropout)         (None, 8, 8, 128)         0
#
#  conv2d_5 (Conv2D)           (None, 8, 8, 128)         147584
#
#  max_pooling2d_2 (MaxPooling  (None, 4, 4, 128)        0
#  2D)
#
#  flatten (Flatten)           (None, 2048)              0
#
#  dropout_3 (Dropout)         (None, 2048)              0
#
#  dense (Dense)               (None, 1024)              2098176
#
#  dropout_4 (Dropout)         (None, 1024)              0
#
#  dense_1 (Dense)             (None, 512)               524800
#
#  dropout_5 (Dropout)         (None, 512)               0
#
#  dense_2 (Dense)             (None, 10)                5130
#
# =================================================================
# Total params: 2,915,114
# Trainable params: 2,915,114
# Non-trainable params: 0
# _________________________________________________________________
# /usr/local/lib/python3.9/dist-packages/keras/optimizers/optimizer_v2/gradient_descent.py:114: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# None
# Epoch 1/30
# 782/782 [==============================] - 312s 398ms/step - loss: 1.9228 - accuracy: 0.2872 - val_loss: 1.6358 - val_accuracy: 0.4046
# Epoch 2/30
# 782/782 [==============================] - 315s 402ms/step - loss: 1.5020 - accuracy: 0.4528 - val_loss: 1.3741 - val_accuracy: 0.5041
# Epoch 3/30
# 782/782 [==============================] - 309s 395ms/step - loss: 1.3063 - accuracy: 0.5281 - val_loss: 1.2081 - val_accuracy: 0.5654
# Epoch 4/30
# 782/782 [==============================] - 310s 397ms/step - loss: 1.1652 - accuracy: 0.5807 - val_loss: 1.0576 - val_accuracy: 0.6216
# Epoch 5/30
# 782/782 [==============================] - 308s 394ms/step - loss: 1.0561 - accuracy: 0.6219 - val_loss: 0.9787 - val_accuracy: 0.6488
# Epoch 6/30
# 782/782 [==============================] - 308s 393ms/step - loss: 0.9586 - accuracy: 0.6571 - val_loss: 0.9762 - val_accuracy: 0.6607
# Epoch 7/30
# 782/782 [==============================] - 307s 393ms/step - loss: 0.8816 - accuracy: 0.6868 - val_loss: 0.8621 - val_accuracy: 0.6948
# Epoch 8/30
# 782/782 [==============================] - 309s 396ms/step - loss: 0.8201 - accuracy: 0.7101 - val_loss: 0.8071 - val_accuracy: 0.7204
# Epoch 9/30
# 782/782 [==============================] - 309s 396ms/step - loss: 0.7668 - accuracy: 0.7298 - val_loss: 0.7646 - val_accuracy: 0.7348
# Epoch 10/30
# 782/782 [==============================] - 309s 395ms/step - loss: 0.7222 - accuracy: 0.7453 - val_loss: 0.7325 - val_accuracy: 0.7466
# Epoch 11/30
# 782/782 [==============================] - 307s 393ms/step - loss: 0.6803 - accuracy: 0.7566 - val_loss: 0.7112 - val_accuracy: 0.7503
# Epoch 12/30
# 782/782 [==============================] - 309s 395ms/step - loss: 0.6443 - accuracy: 0.7742 - val_loss: 0.6922 - val_accuracy: 0.7594
# Epoch 13/30
# 782/782 [==============================] - 308s 394ms/step - loss: 0.6143 - accuracy: 0.7834 - val_loss: 0.6792 - val_accuracy: 0.7651
# Epoch 14/30
# 782/782 [==============================] - 309s 396ms/step - loss: 0.5850 - accuracy: 0.7939 - val_loss: 0.6603 - val_accuracy: 0.7705
# Epoch 15/30
# 782/782 [==============================] - 309s 395ms/step - loss: 0.5551 - accuracy: 0.8039 - val_loss: 0.6517 - val_accuracy: 0.7756
# Epoch 16/30
# 782/782 [==============================] - 311s 398ms/step - loss: 0.5316 - accuracy: 0.8124 - val_loss: 0.6472 - val_accuracy: 0.7769
# Epoch 17/30
# 782/782 [==============================] - 310s 397ms/step - loss: 0.5105 - accuracy: 0.8220 - val_loss: 0.6380 - val_accuracy: 0.7831
# Epoch 18/30
# 782/782 [==============================] - 307s 393ms/step - loss: 0.4900 - accuracy: 0.8257 - val_loss: 0.6338 - val_accuracy: 0.7837
# Epoch 19/30
# 782/782 [==============================] - 307s 393ms/step - loss: 0.4703 - accuracy: 0.8330 - val_loss: 0.6221 - val_accuracy: 0.7889
# Epoch 20/30
# 782/782 [==============================] - 305s 390ms/step - loss: 0.4519 - accuracy: 0.8386 - val_loss: 0.6116 - val_accuracy: 0.7917
# Epoch 21/30
# 782/782 [==============================] - 307s 393ms/step - loss: 0.4329 - accuracy: 0.8481 - val_loss: 0.6328 - val_accuracy: 0.7883
# Epoch 22/30
# 782/782 [==============================] - 305s 390ms/step - loss: 0.4198 - accuracy: 0.8498 - val_loss: 0.6066 - val_accuracy: 0.7942
# Epoch 23/30
# 782/782 [==============================] - 305s 390ms/step - loss: 0.4039 - accuracy: 0.8556 - val_loss: 0.6035 - val_accuracy: 0.7943
# Epoch 24/30
# 782/782 [==============================] - 307s 392ms/step - loss: 0.3870 - accuracy: 0.8625 - val_loss: 0.6004 - val_accuracy: 0.7995
# Epoch 25/30
# 782/782 [==============================] - 307s 393ms/step - loss: 0.3757 - accuracy: 0.8663 - val_loss: 0.6063 - val_accuracy: 0.8007
# Epoch 26/30
# 782/782 [==============================] - 308s 393ms/step - loss: 0.3645 - accuracy: 0.8699 - val_loss: 0.6051 - val_accuracy: 0.7996
# Epoch 27/30
# 782/782 [==============================] - 306s 391ms/step - loss: 0.3495 - accuracy: 0.8740 - val_loss: 0.6057 - val_accuracy: 0.8040
# Epoch 28/30
# 782/782 [==============================] - 307s 392ms/step - loss: 0.3362 - accuracy: 0.8783 - val_loss: 0.6161 - val_accuracy: 0.8024
# Epoch 29/30
# 782/782 [==============================] - 309s 395ms/step - loss: 0.3284 - accuracy: 0.8819 - val_loss: 0.5969 - val_accuracy: 0.8061
# Epoch 30/30
# 782/782 [==============================] - 309s 395ms/step - loss: 0.3172 - accuracy: 0.8876 - val_loss: 0.6083 - val_accuracy: 0.8040
# Accuracy: 80.40%
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 6). These functions will not be directly callable after loading.
